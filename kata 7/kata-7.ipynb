# %% [markdown]
# # Ejercicio 1

# %%
newplanet= ''
planets = []

# %% [markdown]
# # Crear ciclo While

# %%
while newplanet != 'done':
    newplanet = input('Ingresa el nombre de un planeta')
    if newplanet != '':
        planets.append(newplanet)
print(planets)
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto', 'done']

# %% [markdown]
# # Ejercicio 2

# %%
def imprimir(planet):
    print(planet)
map(imprimir,planets)
